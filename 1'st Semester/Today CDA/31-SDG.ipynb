# %%
import pandas as pd

# %%
dataset = pd.read_csv("edu_sdg.csv")
dataset
# Out:
#     Countries and areas     Indicator Category  Point estimate  Upper limit  \
# 0            Bangladesh  ANAR Primary    Total            82.7         83.3
# 1            Bangladesh  ANAR Primary     Male            80.1         81.0
# 2            Bangladesh  ANAR Primary   Female            85.3         86.1
# 3            Bangladesh  ANAR Primary    Urban            84.3         85.6
# 4            Bangladesh  ANAR Primary    Rural            82.2         82.9
# ..                  ...           ...      ...             ...          ...
# 155            Zimbabwe  ANAR Primary    Total            90.3         91.2
# 156            Zimbabwe  ANAR Primary     Male            89.2         90.5
# 157            Zimbabwe  ANAR Primary   Female            91.4         92.7
# 158            Zimbabwe  ANAR Primary    Urban            92.8         94.2
# 159            Zimbabwe  ANAR Primary    Rural            89.4         90.5
#
#      Lower limit Time period
# ...

# %%
dataset.describe()
# Out:
#        Point estimate  Upper limit  Lower limit
# count      160.000000   160.000000   160.000000
# mean        84.426875    86.166250    82.684375
# std         15.333442    15.219571    15.532735
# min         25.200000    26.700000    23.800000
# 25%         76.375000    79.325000    74.275000
# 50%         90.350000    92.000000    88.450000
# 75%         96.425000    97.725000    95.000000
# max         99.300000   101.800000    98.100000

# %%
import matplotlib.pyplot as plt
data = dataset.groupby(["Countries and areas"]).mean()
data
# Out:
#                                   Point estimate  Upper limit  Lower limit
# Countries and areas
# Bangladesh                                 82.92        83.78        82.04
# Belarus                                    92.84        94.92        90.74
# Central African Republic                   74.34        76.34        72.38
# Chad                                       46.80        48.40        45.24
# Democratic Republic of the Congo           77.70        79.02        76.40
# Gambia                                     79.68        81.64        77.66
# Ghana                                      81.90        83.36        80.38
# Guinea-Bissau                              69.90        72.10        67.74
# Guyana                                     96.64        97.86        95.42
# Iraq                                       76.88        78.20        75.56
# Kiribati                                   97.40        98.64        96.16
# ...

# %%
plt.plot(data)
