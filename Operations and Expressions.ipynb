# %% [markdown]
# Q1. Mr. Ramesh has purchased a rectangular-shaped land that is 150 m in length and 200 m in breadth. Calculate the area of the land.

# %%
breadth = 200
lenght = 150
Area = lenght * breadth
print(f"Area Of The Land {Area} Meter")
# Out:
# Area Of The Land 30000 Meter

# %% [markdown]
# ---

# %% [markdown]
# Q2. Find whether a number y is a factor of number x.

# %%
x = int(input("X: "))
y = int(input("Y: "))
for i in range(1, x + 1):
    if x % i == 0 and i == y:
        print(f"Yes {y} Is A Factor Of {x}")
        break
else:
    print(f"{y} Is Not A Factor Of {x}")
# Out:
# X:  12
# Y:  2
# Yes 2 Is A Factor Of 12

# %% [markdown]
# ---

# %% [markdown]
# Q3. One way to determine whether an integer is even is to divide the number by 2 and check the remainder. Write a three-line program that prompts for a number, converts the input to an integer, and prints a 0 if the number is even and a 1 if the number is odd.

# %%
# Python: I Can Do Anything In One Line Then What Are Three (Python Is Famous For One Line Code)
# Me: Yah! I Knew That But It's Constraint You Have To Use Three Line
num = int(input("Number: "))
iseven = lambda x: print(0) if x % 2 == 0 else print(1)
iseven(num)
# Out:
# Number:  12
# 0

# %% [markdown]
# ---

# %% [markdown]
# Q4. Write a program to calculate the volume of water in liters when 1 centimeter of waterfalls on 1 hectare.

# %%
h = float(input())
a = float(input())
vol = (h * a) * 1000
print(vol, "is the volume og the water in liters")
# Out:
# 0.01
# 10000
# 100000.0 is the volume og the water in liters

# %% [markdown]
# ---

# %% [markdown]
# Q5. A day has 86,400 secs (24x60x60). Given a number in the range 1 to 86,400, output the current time as hours, minutes, and seconds with a 24-hour clock. For example:70,000 sec is 19 hours, 26 minutes, and 40 seconds.

# %%
time_sec = int(input("Seconds: "))
hour = time_sec // 3600
remain_time_sec = time_sec % 3600
minute = remain_time_sec // 60
remain_time_sec = time_sec % 60
second = remain_time_sec
print(f"Time:\t  {hour}:{minute}:{second}")
# Out:
# Seconds:  70000
# Time:	  19:26:40

# %% [markdown]
# ---

# %% [markdown]
# Q6. A telephone directory has N lines on each page and each page has exactly C columns. An entry in any column has a name with the corresponding telephone number. On
# which page, column, and line is the Xth entry (name and number) present? (Assume that page, line, column numbers, and X all start from 1.)

# %%
import math
p = 4
l = 10
c = 10
find = 325
poss = p * l * c

page = math.ceil(find / (l * c))
line = (l * c) - (poss - find) % l
print(line)
# Out:
# 95

# %% [markdown]
# ---

# %% [markdown]
# Q7. If  the  lengths  of  the  two  parallel  sides  of  a  trapezoid  are X meters  and Y meters, respectively,  and  the  height  is H meters,  what  is  the  area  of  the  trapezoid? Write Python code to output the area.

# %%
X = float(input("X: "))
Y = float(input("Y: "))
H = float(input("H: "))

area_trapezoid = (1/2) * (X + Y) * H
print("Area Of Trapezoid", area_trapezoid)
# Out:
# X:  34
# Y:  23
# H:  46
# Area Of Trapezoid 1311.0

# %% [markdown]
# ---

# %% [markdown]
# Q8. Simple  interest  is  calculated  by  the  product  of  the  principal,  number  of  years,  and interest, all divided by 100. Write code to calculate the simple interest on a principal amount of $10,000 for duration of 5 years with the rate of interest equal to 12.5%.

# %%
amt = 10000
rate = 12.5
year = 5
si = amt * rate * year / 100
print("Simple Interest", si)
# Out:
# Simple Interest 6250.0

# %% [markdown]
# ---

# %% [markdown]
# Q9. Body  massindex (BMI) is a number calculated from a person’s weight and height. According  to  the  Centers  for  Disease  Control  and  Prevention,  the  BMI  is  a  fairly reliable  indicator  of  body  fatness  for  most  people.  BMI  does  not  measure  body  fat directly, but research has shown that BMI correlates to direct measures of body fat, such as underwater weighing and dual-energy X-ray absorptiometry. The formula for BMI is weight/height where weight is in kilograms and height is in meters.
# - Write  a program  that  prompts  for  metric  weight  and  height  and  outputs  the BMI.
# - Write  a  program  that  prompts  for  weight  in  pounds  and  height  in  inches, converts the values to metric, and then calculates the BMI.

# %%
def normalizer(pounds: int, inches: int) -> tuple:
    return pounds * 0.4536, inches * 0.0254
    
def BIM(weight: float, height: float) -> int:
    bim = int(weight / height ** 2)
    return bim

# %%
# First
weight = float(input("Weight: "))
height = float(input("Height: "))
print("Your Body Mass Index", BIM(weight, height))
# Out:
# Weight: 80
# Height: 5
# Your Body Mass Index 3

# %%
# Second
weight = float(input("Weight In Pounds: "))
height = float(input("Height In Inches: "))
w, h = normalizer(weight, height)
print("Your Body Mass Index", BIM(w, h))
# Out:
# Weight In Pounds: 543
# Height In Inches: 45
# Your Body Mass Index 188
